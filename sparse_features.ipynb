# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# # Feature Extract

# %%
# Load training data
train_filepath = "data/train.csv"
traindf = pd.read_csv(train_filepath, sep='\t')
print("Table:", np.shape(traindf))
print("Columns:", traindf.columns)
# Out:
# Table: (232744, 19)
# Columns: Index(['Row', 'Anon Student Id', 'Problem Hierarchy', 'Problem Name',
#        'Problem View', 'Step Name', 'Step Start Time',
#        'First Transaction Time', 'Correct Transaction Time', 'Step End Time',
#        'Step Duration (sec)', 'Correct Step Duration (sec)',
#        'Error Step Duration (sec)', 'Correct First Attempt', 'Incorrects',
#        'Hints', 'Corrects', 'KC(Default)', 'Opportunity(Default)'],
#       dtype='object')

# %% [markdown]
# ## Split unit and section out

# %%
# Split by comma
traindf["Problem Unit"] = traindf.apply(lambda row: row["Problem Hierarchy"].split(',')[0].strip(), axis=1)
traindf["Problem Section"] = traindf.apply(lambda row: row["Problem Hierarchy"].split(',')[1].strip(), axis=1)

# %%
# Overview of train data
traindf.head(100)
# Out:
#       Row Anon Student Id                Problem Hierarchy Problem Name  \
# 0    9938      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 1    9939      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 2    9940      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 3    9941      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 4    9942      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 5    9943      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 6    9944      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 7    9945      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 8    9946      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 9    9947      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 10   9948      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 11   9949      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 12   9950      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 13   9951      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 14   9952      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 15   9953      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 16   9954      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 17   9955      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 18   9956      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 19   9957      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 20   9958      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 21   9959      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 22   9960      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 23   9961      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 24   9962      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP07
# 25   9963      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP08
# 26   9964      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP08
# 27   9965      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP08
# 28   9966      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP08
# 29   9967      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP08
# ..    ...             ...                              ...          ...
# 70  10008      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 71  10009      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 72  10010      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 73  10011      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 74  10012      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 75  10013      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 76  10014      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 77  10015      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 78  10016      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 79  10017      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP12
# 80  10018      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 81  10019      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 82  10020      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 83  10021      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 84  10022      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 85  10023      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 86  10024      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 87  10025      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 88  10026      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 89  10027      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 90  10028      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 91  10029      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP02
# 92  10030      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 93  10031      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 94  10032      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 95  10033      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 96  10034      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 97  10035      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 98  10036      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 99  10037      52vEY7f17k  Unit CTA1_13, Section CTA1_13-
# 8   ...                         13.0                        NaN
# 9   ...                          NaN                       43.0
# 10  ...                         23.0                        NaN
# 11  ...                          NaN                      176.0
# 12  ...                         10.0                        NaN
# 13  ...                          8.0                        NaN
# 14  ...                          8.0                        NaN
# 15  ...                        120.0                        NaN
# 16  ...                          NaN                        6.0
# 17  ...                          NaN                      122.0
# 18  ...                          7.0                        NaN
# 19  ...                          9.0                        NaN
# 20  ...                         24.0                        NaN
# 21  ...                         20.0                        NaN
# 22  ...                          5.0                        NaN
# 23  ...                          NaN                       76.0
# 24  ...                          NaN                       68.0
# 25  ...                         13.0                        NaN
# 26  ...                         10.0                        NaN
# 27  ...                          3.0                        NaN
# 28  ...                         12.0                        NaN
# 29  ...                          7.0                        NaN
# ..  ...                          ...                        ...
# 70  ...                          7.0                        NaN
# 71  ...                          NaN                       39.0
# 72  ...                          NaN                      147.0
# 73  ...                         64.0                        NaN
# 74  ...                          3.0                        NaN
# 75  ...                          9.0                        NaN
# 76  ...                          8.0                        NaN
# 77  ...                          NaN                      232.0
# 78  ...                         45.0                        NaN
# 79  ...                          5.0                        NaN
# 80  ...                         12.0                        NaN
# 81  ...                          5.0                        NaN
# 82  ...                          3.0                        NaN
# 83  ...                         11.0                        NaN
# 84  ...                          7.0                        NaN
# 85  ...                          5.0                        NaN
# 86  ...                          7.0                        NaN
# 87  ...                          6.0                        NaN
# 88  ...                         55.0                        NaN
# 89  ...                          3.0                        NaN
# 90  ...                          5.0                        NaN
# 91  ...                          NaN                        9.0
# 92  ...                         14.0                        NaN
# 93  ...                          6.0                        NaN
# 94  ...                          1.0                        NaN
# 95  ...                         28.0                        NaN
# 96  ...                          6.0                        NaN
# 97  ...                          6.0                        NaN
# 98  ...                          7.0                        NaN
# 99  ...                          7.0                        NaN
#
#     Correct First Attempt  Incorrects  Hints  Corrects  \
# 0                       1           0      0         1
# 1                       1           0      0         1
# 2                       0           2      0         1
# 3                       0           4      9         1
# 4                       1           0      0         1
# 5                       1           0      0         1
# 6                       1           0      0         1
# 7                       1           0      0         1
# 8                       1           0      0         2
# 9                       0           1      0         1
# 10                      1           0      0         1
# 11                      0           1      4         1
# 12                      1           0      0         1
# 13                      1           0      0         1
# 14                      1           0      0         1
# 15                      1           0      0         1
# 16                      0           1      0         0
# 17                      0           2      0         1
# 18                      1           0      0         1
# 19                      1           0      0         1
# 20                      1           0      0         1
# 21                      1           0      0         2
# 22                      1           0      0         1
# 23                      0           1      0         1
# 24                      0           0      4         1
# 25                      1           0      0         1
# 26                      1           0      0         1
# 27                      1           0      0         1
# 28                      1           0      0         1
# 29                      1           0      0         1
# ..                    ...         ...    ...       ...
# 70                      1           0      0         1
# 71                      0           1      0         1
# 72                      0           2      0         0
# 73                      1           0      0         2
# 74                      1           0      0         1
# 75                      1           0      0         1
# 76                      1           0      0         1
# 77                      0           5      5         1
# 78                      1           0      0         1
# 79                      1           0      0         1
# 80                      1           0      0         1
# 81                      1           0      0         1
# 82                      1           0      0         1
# 83                      1           0      0         1
# 84                      1           0      0         1
# 85                      1           0      0         1
# 86                      1           0      0         1
# 87                      1           0      0         1
# 88                      1           0      0         2
# 89                      1           0      0         1
# 90                      1           0      0         1
# 91                      0           1      0         1
# 92                      1           0      0         1
# 93                      1           0      0         1
# 94                      1           0      0         1
# 95                      1           0      0         1
# 96                      1           0      0         1
# 97                      1           0      0         1
# 98                      1           0      0         1
# 99                      1           0      0         1
#
#                                           KC(Default) Opportunity(Default)  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2                                     Define Variable                    1
# 3   Using small numbers~~Write expression, positiv...              1~~1~~1
# 4                                    Entering a given                    1
# 5                                    Entering a given                    2
# 6                                    Entering a given                    3
# 7                                    Entering a given                    4
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11  Using small numbers~~Find X, Simple~~Using dif...              2~~1~~2
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                    Define Variable                    2
# 15  Using small numbers~~Write expression, positiv...              3~~2~~3
# 16  Find Y, Simple~~Using small numbers~~Using dif...              1~~4~~4
# 17                                   Entering a given                    5
# 18                                   Entering a given                    6
# 19                                   Entering a given                    7
# 20                                   Entering a given                    8
# 21                                                NaN                  NaN
# 22                                                NaN                  NaN
# 23                                                NaN                  NaN
# 24  Using small numbers~~Find X, Simple~~Using dif...              5~~2~~5
# 25                                                NaN                  NaN
# 26                                                NaN                  NaN
# 27                                    Define Variable                    3
# 28  Using small numbers~~Write expression, positiv...              6~~3~~6
# 29                                   Entering a given                    9
# ..                                                ...                  ...
# 70                                    Define Variable                    6
# 71  Using small numbers~~Write expression, positiv...            17~~6~~17
# 72                                   Entering a given                   21
# 73                                                NaN                  NaN
# 74                                                NaN                  NaN
# 75  [SkillRule: Eliminate Parens; {CLT nested; CLT...                 1~~4
# 76  [SkillRule: Remove positive coefficient; {ax/b...                 4~~5
# 77  Using small numbers~~Find X, Simple~~Using dif...            18~~7~~18
# 78                                   Entering a given                   22
# 79                                   Entering a given                   23
# 80                                                NaN                  NaN
# 81                                                NaN                  NaN
# 82                                    Define Variable                    7
# 83  Using small numbers~~Write expression, positiv...            19~~7~~19
# 84                                   Entering a given                   24
# 85                                   Entering a given                   25
# 86                                   Entering a given                   26
# 87                                   Entering a given                   27
# 88                                                NaN                  NaN
# 89                                                NaN                  NaN
# 90  [SkillRule: Remove positive coefficient; {ax/b...                 5~~6
# 91  Using small numbers~~Find X, Simple~~Using dif...            20~~8~~20
# 92                                                NaN                  NaN
# 93                                                NaN                  NaN
# 94                                    Define Variable                    8
# 95  Using difficult numbers~~Using small numbers~~...            21~~21~~8
# 96                                   Entering a given                   28
# 97                                   Entering a given                   29
# 98                                   Entering a given                   30
# 99                                   Entering a given                   31
#
#     Problem Unit    Problem Section
# 0   Unit CTA1_13  Section CTA1_13-1
# 1   Unit CTA1_13  Section CTA1_13-1
# 2   Unit CTA1_13  Section CTA1_13-1
# 3   Unit CTA1_13  Section CTA1_13-1
# 4   Unit CTA1_13  Section CTA1_13-1
# 5   Unit CTA1_13  Section CTA1_13-1
# 6   Unit CTA1_13  Section CTA1_13-1
# 7   Unit CTA1_13  Section CTA1_13-1
# 8   Unit CTA1_13  Section CTA1_13-1
# 9   Unit CTA1_13  Section CTA1_13-1
# 10  Unit CTA1_13  Section CTA1_13-1
# 11  Unit CTA1_13  Section CTA1_13-1
# 12  Unit CTA1_13  Section CTA1_13-1
# 13  Unit CTA1_13  Section CTA1_13-1
# 14  Unit CTA1_13  Section CTA1_13-1
# 15  Unit CTA1_13  Section CTA1_13-1
# 16  Unit CTA1_13  Section CTA1_13-1
# 17  Unit CTA1_13  Section CTA1_13-1
# 18  Unit CTA1_13  Section CTA1_13-1
# 19  Unit CTA1_13  Section CTA1_13-1
# 20  Unit CTA1_13  Section CTA1_13-1
# 21  Unit CTA1_13  Section CTA1_13-1
# 22  Unit CTA1_13  Section CTA1_13-1
# 23  Unit CTA1_13  Section CTA1_13-1
# 24  Unit CTA1_13  Section CTA1_13-1
# 25  Unit CTA1_13  Section CTA1_13-1
# 26  Unit CTA1_13  Section CTA1_13-1
# 27  Unit CTA1_13  Section CTA1_13-1
# 28  Unit CTA1_13  Section CTA1_13-1
# 29  Unit CTA1_13  Section CTA1_13-1
# ..           ...                ...
# 70  Unit CTA1_13  Section CTA1_13-1
# 71  Unit CTA1_13  Section CTA1_13-1
# 72  Unit CTA1_13  Section CTA1_13-1
# 73  Unit CTA1_13  Section CTA1_13-1
# 74  Unit CTA1_13  Section CTA1_13-1
# 75  Unit CTA1_13  Section CTA1_13-1
# 76  Unit CTA1_13  Section CTA1_13-1
# 77  Unit CTA1_13  Section CTA1_13-1
# 78  Unit CTA1_13  Section CTA1_13-1
# 79  Unit CTA1_13  Section CTA1_13-1
# 80  Unit CTA1_13  Section CTA1_13-1
# 81  Unit CTA1_13  Section CTA1_13-1
# 82  Unit CTA1_13  Section CTA1_13-1
# 83  Unit CTA1_13  Section CTA1_13-1
# 84  Unit CTA1_13  Section CTA1_13-1
# 85  Unit CTA1_13  Section CTA1_13-1
# 86  Unit CTA1_13  Section CTA1_13-1
# 87  Unit CTA1_13  Section CTA1_13-1
# 88  Unit CTA1_13  Section CTA1_13-1
# 89  Unit CTA1_13  Section CTA1_13-1
# 90  Unit CTA1_13  Section CTA1_13-1
# 91  Unit CTA1_13  Section CTA1_13-1
# 92  Unit CTA1_13  Section CTA1_13-1
# 93  Unit CTA1_13  Section CTA1_13-1
# 94  Unit CTA1_13  Section CTA1_13-1
# 95  Unit CTA1_13  Section CTA1_13-1
# 96  Unit CTA1_13  Section CTA1_13-1
# 97  Unit CTA1_13  Section CTA1_13-1
# 98  Unit CTA1_13  Section CTA1_13-1
# 99  Unit CTA1_13  Section CTA1_13-1
#
# [100 rows x 21 columns]

# %% [markdown]
# ## Extract one-hot feature

# %%
def one_dim_split(df, col):
    cols = set(df[col])
    numcols = len(cols)
    print("Column %s has %d values, so we will be adding as many columns to this dataframe" % (col, numcols))
    
    # Row number
    numrows = len(df)

    # Create df
    newdf = pd.DataFrame(np.zeros((numrows, numcols)), index=df.index, columns=list(cols))

    # For each value in the dataframe, mark the corresponding column as 1
    for c in cols:
        newdf.loc[df[col] == c, c] = 1

    return newdf

# %% [markdown]
# ### One-dimensional Feature

# %% [markdown]
# #### Problem Units

# %%
pu_features = one_dim_split(traindf, "Problem Unit")
# Out:
# Column Problem Unit has 32 values, so we will be adding as many columns to this dataframe

# %%
# Save
pu_features.to_csv("data/pu-sparse-features.csv")

# %% [markdown]
# #### Problem Sections

# %%
ps_features = one_dim_split(traindf, "Problem Section")
# Out:
# Column Problem Section has 138 values, so we will be adding as many columns to this dataframe

# %%
# Save
ps_features.to_csv("data/ps-sparse-features.csv")

# %% [markdown]
# #### Problem Name

# %%
pn_features = one_dim_split(traindf, "Problem Name")
# Out:
# Column Problem Name has 1021 values, so we will be adding as many columns to this dataframe

# %%
# Save
pn_features.to_csv("data/pn-sparse-features.csv")

# %% [markdown]
# #### Step Name

# %%
sn_features = one_dim_split(traindf, "Step Name")
# Out:
# Column Step Name has 60709 values, so we will be adding as many columns to this dataframe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-a18dd66a079e> in <module>
# ----> 1 sn_features = one_dim_split(traindf, "Step Name")
#
# <ipython-input-30-3bb8d1ecf6c9> in one_dim_split(df, col)
#      12     # For each value in the dataframe, mark the corresponding column as 1
#      13     for c in cols:
# ---> 14         newdf.loc[df[col] == c, c] = 1
#      15
#      16     return newdf
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# KeyboardInterrupt:

# %%
sn_features.to_csv("data/sn-sparse-features.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-62f46fdfcd48> in <module>
# ----> 1 traindf.to_csv("data/1d-sparse-features.csv")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# --> 172             self._save()
#     173
#     174         finally:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save(self)
#     286                 break
#     287
# --> 288             self._save_chunk(start_i, end_i)
#     289
#     290     def _save_chunk(self, start_i, end_i):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     300                                   decimal=self.decimal,
#     301                                   date_format=self.date_format,
# --> 302                                   quoting=self.quoting)
#     303
#     304             for col_loc, col in zip(b.mgr_locs, d):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals/blocks.py in to_native_types(self, slicer, na_rep, float_format, decimal, quoting, **kwargs)
#    1995
#    1996             if not quoting:
# -> 1997                 values = values.astype(str)
#    1998             else:
#    1999                 values = np.array(values, dtype='object')
#
# KeyboardInterrupt:
